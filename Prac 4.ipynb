# %%
import pandas as pd
df = pd.read_csv("dff.csv")
print(df.head())
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa

# %%
df['Sepal.Length'].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: Sepal.Length, dtype: float64

# %%
df.groupby('Species')['Petal.Length'].describe()
# Out:
#             count   mean       std  min  25%   50%    75%  max
# Species
# setosa       50.0  1.462  0.173664  1.0  1.4  1.50  1.575  1.9
# versicolor   50.0  4.260  0.469911  3.0  4.0  4.35  4.600  5.1
# virginica    50.0  5.552  0.551895  4.5  5.1  5.55  5.875  6.9

# %%
df['Sepal.Length'].quantile([0.25,0.50,0.75])
# Out:
# 0.25    5.1
# 0.50    5.8
# 0.75    6.4
# Name: Sepal.Length, dtype: float64

# %%
df[['Petal.Length','Petal.Width']].corr()
# Out:
#               Petal.Length  Petal.Width
# Petal.Length      1.000000     0.962865
# Petal.Width       0.962865     1.000000

# %%
df['Sepal.Width'].value_counts()
# Out:
# Sepal.Width
# 3.0    26
# 2.8    14
# 3.2    13
# 3.4    12
# 3.1    11
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.6     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: count, dtype: int64

# %%
df['Species'].value_counts()
# Out:
# Species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.groupby('Species').mean()
# Out:
#             Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Species
# setosa            25.5         5.006        3.428         1.462        0.246
# versicolor        75.5         5.936        2.770         4.260        1.326
# virginica        125.5         6.588        2.974         5.552        2.026

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.hist(df['Sepal.Length'],bins=10)
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot([df[df.Species==s]['Petal.Length']for s in df.Species.unique()])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x112c2358980>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x112c2358c20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x112c2358830>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x112c2358ec0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x112c2359010>,
# ...
#  'means': []}

# %%
plt.boxplot(df['Sepal.Width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x112c23b9fd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x112c23ba270>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x112c23b9e80>],
#  'medians': [<matplotlib.lines.Line2D at 0x112c23ba510>],
#  'fliers': [<matplotlib.lines.Line2D at 0x112c23ba660>],
#  'means': []}

# %%
plt.figur()
