# %%
import numpy as np
import matplotlib.pyplot as plt 
dff=np.random.normal(2,3,1000)
print(np.mean(dff))
print(np.median(dff))
plt.hist(dff)
plt.show()
plt.boxplot(dff)
# Out:
# 2.087260605779363
# 2.2269484160473647
# {'whiskers': [<matplotlib.lines.Line2D at 0x269f44c1940>,
#   <matplotlib.lines.Line2D at 0x269f44c1a90>],
#  'caps': [<matplotlib.lines.Line2D at 0x269f44c1be0>,
#   <matplotlib.lines.Line2D at 0x269f44c1d30>],
#  'boxes': [<matplotlib.lines.Line2D at 0x269f44c17f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x269f44c1e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x269f44c1fd0>],
#  'means': []}

# %%
# !pip install scipy
import numpy as np
from scipy.stats import norm, uniform, binom

# 1. Normal (Gaussian) distribution
samples_normal = norm.rvs(loc=0, scale=1, size=1000)
plt.hist(samples_normal)

# 2. Uniform distribution
samples_uniform = uniform.rvs(loc=0, scale=10, size=1000)

# 3. Binomial (discrete) distribution
samples_binomial = binom.rvs(n=10, p=0.5, size=1000)
ss.stats.norm.pmf(2,3,1000)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in c:\users\math lab\appdata\roaming\python\python314\site-packages (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\program files\python\lib\site-packages (from scipy) (2.4.0)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 14
#      12 # 3. Binomial (discrete) distribution
#      13 samples_binomial = binom.rvs(n=10, p=0.5, size=1000)
# ---> 14 ss.stats.norm.pmf(2,3,1000)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\scipy\stats\stats.py:39, in __getattr__(name)
#      38 def __getattr__(name):
# ---> 39     return _sub_module_deprecation(sub_package="stats", module="stats",
#      40                                    private_modules=["_stats_py", "_mgc"], all=__all__,
#      41                                    attribute=name)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\scipy\_lib\deprecation.py:45, in _sub_module_deprecation(sub_package, module, private_modules, all, attribute, correct_module, dep_version)
#      42     correct_import = f"scipy.{sub_package}"
#      44 if attribute not in all:
# ---> 45     raise AttributeError(
#      46         f"`scipy.{sub_package}.{module}` has no attribute `{attribute}`; "
#      47         f"furthermore, `scipy.{sub_package}.{module}` is deprecated "
#      48         f"and will be removed in SciPy 2.0.0."
#      49     )
#      51 attr = getattr(import_module(correct_import), attribute, None)
#      53 if attr is not None:
#
# AttributeError: `scipy.stats.stats` has no attribute `norm`; furthermore, `scipy.stats.stats` is deprecated and will be removed in SciPy 2.0.0.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as ss
mu, sigma=100,10

# %%
rnd_sample=np.random.normal(mu,sigma,(1000,100))

# %%
n=[10,20,30,50,75,100]

# %%
plt.hist(df,bins=30)
plt.show()

# %%
df=rnd_sample[:,:n[5]].mean(axis=1)
plt.hist(df,bins=30)
plt.show()

# %%
fig, ax = plt.subplots(nrows = 2,ncols = 3,figsize = (16,6))

df=rnd_sample[:,:n[0]].mean(axis=1)
ax[0,0].hist(df,bins=30,density=True)
ax[0,0].set_title("n=10")
df=rnd_sample[:,:n[1]].mean(axis=1)
ax[0,1].hist(df,bins=30)
ax[0,1].set_title("n=20")
df=rnd_sample[:,:n[2]].mean(axis=1)
ax[0,2].hist(df,bins=30)
ax[0,2].set_title("n=30")

df=rnd_sample[:,:n[3]].mean(axis=1)
ax[1,0].hist(df,bins=30)
ax[1,0].set_title("n=50")
df=rnd_sample[:,:n[4]].mean(axis=1)
ax[1,1].hist(df,bins=30)
ax[1,1].set_title("n=60")
df=rnd_sample[:,:n[5]].mean(axis=1)
ax[1,2].hist(df,bins=30)
ax[1,2].set_title("n=70")
# Out:
# Text(0.5, 1.0, 'n=70')

# %%
dmf=np.random.uniform(0,1,1000)
print(np.max(dmf))
plt.hist(dmf)
plt.show()
plt.boxplot(dmf)
# Out:
# 0.9997223153354213
# {'whiskers': [<matplotlib.lines.Line2D at 0x269fd9ec830>,
#   <matplotlib.lines.Line2D at 0x269fd9ec980>],
#  'caps': [<matplotlib.lines.Line2D at 0x269fd9ecad0>,
#   <matplotlib.lines.Line2D at 0x269fd9ecc20>],
#  'boxes': [<matplotlib.lines.Line2D at 0x269fd9ec6e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x269fd9ecd70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x269fd9ecec0>],
#  'means': []}

# %%
rnd_sample=np.random.uniform(0,1,1000)
n=[10,20,30,50,75,100]
print(np.max(dmf))
fig, ax = plt.subplots(nrows = 2,ncols = 3,figsize = (6,6))

df=rnd_sample[:,:n[0]].mean(axis=1)
ax[0,0].hist(df,bins=30)
ax[0,0].set_title("n=10")
df=rnd_sample[:,:n[1]].mean(axis=1)
ax[0,1].hist(df,bins=30)
ax[0,1].set_title("n=20")
df=rnd_sample[:,:n[2]].mean(axis=1)
ax[0,2].hist(df,bins=30)
ax[0,2].set_title("n=30")

df=rnd_sample[:,:n[3]].mean(axis=1)
ax[1,0].hist(df,bins=30)
ax[1,0].set_title("n=50")
df=rnd_sample[:,:n[4]].mean(axis=1)
ax[1,1].hist(df,bins=30)
ax[1,1].set_title("n=60")
df=rnd_sample[:,:n[5]].mean(axis=1)
ax[1,2].hist(df,bins=30)
ax[1,2].set_title("n=70")
# Out:
# 0.9997223153354213
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[81], line 6
#       3 print(np.max(dmf))
#       4 fig, ax = plt.subplots(nrows = 2,ncols = 3,figsize = (6,6))
# ----> 6 df=rnd_sample[:,:n[0]].mean(axis=1)
#       7 ax[0,0].hist(df,bins=30)
#       8 ax[0,0].set_title("n=10")
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
